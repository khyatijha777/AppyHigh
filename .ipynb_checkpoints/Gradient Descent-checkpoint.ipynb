# %% [markdown]
# # Gradient descent algorithm

# %% [markdown]
# Gradient descent is an iterative optimization algorithm for finding the minimum of any function. To find a local minimum of a function using gradient descent, one takes steps proportional to the negative of the gradient of the function at the current point. If, instead, one takes steps proportional to the positive of the gradient, one approaches a local maximum of that function; the procedure is then known as gradient ascent.
#
# Gradient descent is also known as steepest descent. fcdf
#
#
# ## Let's discuss some imprtant terms-
# #### 1. Hypothesis function-
# This the function which is used to predict the output for some unknown data.
# Or we can say, the function that besy fits the data is called the hypothesis function.
# #### eg. H(X) = theta[0] + theta[1]*X
# here theta is coefficient of X and is a vector.
#
# ![descend1.png](attachment:descend1.png)
#
# In the above diagram we could have so many hypothesis functions. But all the green lines do not seem to fit the data well.
#
# But the red line seems to fit data in the best way possible. and which line fits the best, this is decides by minimizing the cost function.
#
#
# #### Cost function-
# Cost function when minimized provides value of theta.
#
# #### J(theta) = (sum(h(X)-Y)** 2)/2m
# m-> no of examples

# %% [markdown]
# ## Steps involved-
#
# Here m denotes the number of examples in the training set.
# 1. Calcuation of the hypothesis h = X * theta
# 2. Calculation the loss  = ((h-x)^2)/2m
#     Some othe method can also be used to calculate the loss, in this case we are using suare error function
# 3. Calculation of the gradient = X' * loss / m
# 4. Updation of the parameters theta = theta - alpha * gradient
# 5. The gardient descend will stop when the gradient becomes 0 as at this point we get local minima.
# ![gradient2.png](attachment:gradient2.png)

# %% [markdown]
# ## Python implementation

# %%
import numpy as np
import random

# %%
def gradientDescent(x, y, theta, alpha, m, numIterations):
    xTrans = x.transpose()
    for i in range(0, numIterations):
        hypothesis = np.dot(x, theta)
        loss = hypothesis - y
        # avg cost per example (the 2 in 2*m doesn't really matter here.
        # But to be consistent with the gradient, I include it)
        cost = np.sum(loss ** 2) / (2 * m)
        print("Iteration %d | Cost: %f" % (i, cost))
        # avg gradient per example
        gradient = np.dot(xTrans, loss) / m
        # update
        theta = theta - alpha * gradient
    return theta


def genData(numPoints, bias, variance):
    x = np.zeros(shape=(numPoints, 2))
    y = np.zeros(shape=numPoints)
    # basically a straight line
    for i in range(0, numPoints):
        # bias feature
        x[i][0] = 1
        x[i][1] = i
        # our target variable
        y[i] = (i + bias) + random.uniform(0, 1) * variance
    return x, y

# gen 100 points with a bias of 25 and 10 variance as a bit of noise
x, y = genData(100, 25, 10)
m, n = np.shape(x)
numIterations= 1000
alpha = 0.0005
theta = np.ones(n)
theta = gradientDescent(x, y, theta, alpha, m, numIterations)
print(theta)
# Out:
# Iteration 0 | Cost: 442.177710
# Iteration 1 | Cost: 247.748324
# Iteration 2 | Cost: 167.564755
# Iteration 3 | Cost: 134.487268
# Iteration 4 | Cost: 120.832665
# Iteration 5 | Cost: 115.186551
# Iteration 6 | Cost: 112.842519
# Iteration 7 | Cost: 111.860012
# Iteration 8 | Cost: 111.438897
# Iteration 9 | Cost: 111.249259
# Iteration 10 | Cost: 111.155069
# Iteration 11 | Cost: 111.100238
# Iteration 12 | Cost: 111.061640
# Iteration 13 | Cost: 111.029739
# Iteration 14 | Cost: 111.000603
# Iteration 15 | Cost: 110.972612
# Iteration 16 | Cost: 110.945096
# Iteration 17 | Cost: 110.917781
# Iteration 18 | Cost: 110.890553
# Iteration 19 | Cost: 110.863364
# Iteration 20 | Cost: 110.836196
# Iteration 21 | Cost: 110.809040
# Iteration 22 | Cost: 110.781893
# Iteration 23 | Cost: 110.754754
# Iteration 24 | Cost: 110.727623
# Iteration 25 | Cost: 110.700498
# Iteration 26 | Cost: 110.673381
# Iteration 27 | Cost: 110.646270
# Iteration 28 | Cost: 110.619166
# ...
